# %%
#import kaggle       
#kaggle.api.authenticate()
#kaggle.api.dataset_download_files('API command here', path='Resources', unzip=True)

#API commands used from Kaggle:
#Boston: AnalyzeBoston/crimes-in-boston
#Baltimore: sohier/crime-in-baltimore
#Philadelphia: mchirico/philadelphiacrimedata
#Solar & Lunar: nasa/solar-eclipses
#Full Moon: lsind18/full-moon-calendar-1900-2050

# %%
# #Dependencies
# import pandas as pd
# import numpy as np
# import os
# import time

# #File load
# boston = "Resources/boston_crime_data.csv"
# philadelphia = "Resources/philadelphia_crime_data.csv"
# baltimore = "Resources/balitmore_crime_data.csv"

# #Read file and store into pandas data frame
# boston_data_df = pd.read_csv(boston, sep = ',')
# philadelphia_data_df = pd.read_csv(philadelphia, sep = ',')
# baltimore_data_df = pd.read_csv(baltimore, sep = ',')

# %%
#boston_data_df.head()
#baltimore_data_df.head()
#philadelphia_data_df.head()

# %%
# #Sort through data to make smaller, finding only requested year
# #Philadephia
# philadelphia_data_df['Dispatch_Date']= pd.to_datetime(philadelphia_data_df['Dispatch_Date'])
# philadelphia_data_df2 = philadelphia_data_df[philadelphia_data_df['Dispatch_Date'].dt.year == 2016]
# #Also reduce column size to fit into git repository 
# philadelphia_data_df3 = philadelphia_data_df2[['Dispatch_Date', 'Text_General_Code']].copy()
# philadelphia_data_df3['Text_General_Code'].value_counts()

# #Original files too large to upload to GitHub. 
# #Isolated year 2016, selected desired columns then saved and uploaded shortened version
# philadelphia_data_df3.to_csv('Resources/philadelphia_data_df3.csv')

# %%
# #Sort through data to make smaller, finding only requested year
# #Boston
# boston_data_df['OCCURRED_ON_DATE']= pd.to_datetime(boston_data_df['OCCURRED_ON_DATE'])
# boston_data_df2 = boston_data_df[boston_data_df['OCCURRED_ON_DATE'].dt.year == 2016]

# #Original files too large to upload to GitHub. 
# #Isolated year 2016 then saved and uploaded shortened version
# boston_data_df2.to_csv('Resources/boston_data_df3.csv')

# %%
# #Sort through data to make smaller, finding only requested year
# #Baltimore
# baltimore_data_df['CrimeDate']= pd.to_datetime(baltimore_data_df['CrimeDate'])
# baltimore_data_df2 = baltimore_data_df[baltimore_data_df['CrimeDate'].dt.year == 2016]

# #Original files too large to upload to GitHub. 
# #Isolated year 2016 then saved and uploaded shortened version
# baltimore_data_df2.to_csv('Resources/baltimore_data_df3.csv')

# %%
#Dependencies
import pandas as pd
import numpy as np
import os
import time
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import itertools
# %matplotlib inline

#Load files
boston = "Resources/boston_data_df3.csv"
philadelphia = "Resources/philadelphia_data_df3.csv"
baltimore = "Resources/baltimore_data_df3.csv"
solar = "Resources/solar.csv"
lunar = "Resources/lunar.csv"
full_moon = "Resources/full_moon.csv"


#Read file and store into pandas data frame
boston_df = pd.read_csv(boston, sep = ',')
philadelphia_crime_2016 = pd.read_csv(philadelphia, sep = ',')
baltimore_df = pd.read_csv(baltimore, sep = ',')
solar_df = pd.read_csv(solar, sep = ',')
lunar_df = pd.read_csv(lunar, sep = ',')
full_moon_data_df = pd.read_csv(full_moon, sep = ',')

# %%
#Shorten  data frames to get just desired columns
#Boston
boston_crime_2016 = boston_df[['OCCURRED_ON_DATE','OFFENSE_CODE_GROUP' ,'OFFENSE_DESCRIPTION']].copy()
boston_crime_2016['OCCURRED_ON_DATE'] = pd.to_datetime(boston_crime_2016['OCCURRED_ON_DATE']).dt.normalize()
boston_crime_2016.rename(columns = {'OCCURRED_ON_DATE':'Crime Date', 'OFFENSE_CODE_GROUP':'Offense Description',
                                    'OFFENSE_DESCRIPTION':'Offense Specific' }, inplace = True)
boston_crime_drop = boston_crime_2016.drop('Offense Specific', 1)

#Baltimore
baltimore_crime_2016 = baltimore_df[['CrimeDate', 'Description', 'Weapon']].copy()
baltimore_crime_2016.rename(columns = {'CrimeDate':'Crime Date', 'Description':'Offense Description'}, inplace = True)
# baltimore_data_df3['Description'].value_counts()

#Philadelphia: 
# data already redcued in order to fit in git hub repository
philadelphia_crime_2016.rename(columns = {'Unnamed: 0': 'Prior Index', 'Dispatch_Date':'Crime Date', 'Text_General_Code':'Offense Description'}, inplace = True)
philadelphia_crime_2016['Crime Date'] = pd.to_datetime(philadelphia_crime_2016['Crime Date']).dt.normalize()
#del philadelphia_crime_2016['Unnamed: 0']

#Solar eclipse
#sort desired columns
solar_data_df = solar_df[['Calendar Date', 'Eclipse Time', 'Gamma', 'Eclipse Magnitude']].copy()
#sort desired year
solar_data_df['Calendar Date']= pd.to_datetime(solar_data_df['Calendar Date'], errors = 'coerce')
solar_eclipse_2016 = solar_data_df[solar_data_df['Calendar Date'].dt.year == 2016]

#Lunar eclipse
#sort desired columns
lunar_data_df = lunar_df[['Calendar Date', 'Eclipse Time', 'Gamma', 'Penumbral Eclipse Duration (m)', \
                             'Partial Eclipse Duration (m)', 'Total Eclipse Duration (m)']].copy()
#sort desired year
lunar_data_df['Calendar Date']= pd.to_datetime(lunar_data_df['Calendar Date'], errors = 'coerce')
lunar_eclipse_2016 = lunar_data_df[lunar_data_df['Calendar Date'].dt.year == 2016]

#Full Moon
#fix columns by renaming (removing space before name)
full_moon_data_df.columns = ['Day', 'Calendar Date', 'Time']

#set column date as date_time and sort to get desired year
full_moon_data_df['Calendar Date']= pd.to_datetime(full_moon_data_df['Calendar Date'])
full_moon_2016 = full_moon_data_df[full_moon_data_df['Calendar Date'].dt.year == 2016]

# %%
#boston_crime_2016.head()
#baltimore_crime_2016.head(20)
#philadelphia_crime_2016.head(20)
#solar_eclipse_2016.head()
#lunar_eclipse_2016.head()
#full_moon_2016

# %%
## Other styples of Bar Graphs

#value_count = boston_crime_feb['Crime Date'].value_counts()
#value_count = boston_crime_feb['Crime Date'].value_counts(sort=False)

#month_values = boston_crime_feb['Crime Date'].unique()
#boston_crime_feb_test = boston_crime_feb['Crime Day': ]
#day = mdates.DayLocator()

#lists = sorted(itertools.izip(*[month_values, value_count]))
#new_x, new_y = zip(*sorted(zip(month_values, value_count)))
#sns.barplot(x = month_values, y= value_count)

# x= np.arange(len(month_values))
# fig, ax = plt.subplots()
# ax.bar(month_values, value_count)
# ax.set_xticks(x)
# ax.set_xticklabels(month_values)

#boston_crime_feb_group = boston_crime_feb.groupby(['Crime Date'])
#boston_crime_feb_group.count().plot(kind='bar')

#boston_crime_feb['Crime Date'].value_counts().sort_index().plot(kind='bar')
#x_axis.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# %%
#Philadelphia Crime January Data
philadelphia_crime_jan_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 1]
philadelphia_crime_jan = philadelphia_crime_jan_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_jan_24 = philadelphia_crime_jan[philadelphia_crime_jan['Crime Date'].dt.day == 24]

day_average = f'{((philadelphia_crime_jan_24["Crime Date"].count()/philadelphia_crime_jan["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_jan["Crime Date"].count()/31)}'

df_total_jan = pd.DataFrame(philadelphia_crime_jan['Crime Date'].value_counts())
df_total_jan.columns = ['Reported Crime']
df_total_jan['Rank'] = df_total_jan['Reported Crime'].rank(ascending=0)
philadelphia_jan_max = df_total_jan['Reported Crime'].max()
philadelphia_jan_min = df_total_jan['Reported Crime'].min()


print(f'January in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_jan["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_jan_max}')
print(f'The minimum crime committed on one day: {philadelphia_jan_min}')
print(f'Total crime on full moon (Jan 24th): {philadelphia_crime_jan_24["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 30/31')
#df_total_jan
# Out:
# January in Philadelphia:
# Total number of crimes reported: 12042
# Average number of crimes per day for whole month: 388
# The maximum crime committed on one day: 515
# The minimum crime committed on one day: 71
# Total crime on full moon (Jan 24th): 157
# Percentage of monthy crime that occured on day of the full moon: 1.3%
# Rank of crime on full moon: 30/31

# %%
#philadelphia Crime January Plot
#Sort index by date 2and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_jan['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,550)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('January 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=157, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/jan_2016.png')
plt.show()

# %%
#Philadelphia Crime Febuary Data
philadelphia_crime_feb_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 2]
philadelphia_crime_feb = philadelphia_crime_feb_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_feb_22 = philadelphia_crime_feb[philadelphia_crime_feb['Crime Date'].dt.day == 22]

day_average = f'{((philadelphia_crime_feb_22["Crime Date"].count()/philadelphia_crime_feb["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_feb["Crime Date"].count()/29)}'

df_total_feb = pd.DataFrame(philadelphia_crime_feb['Crime Date'].value_counts())
df_total_feb.columns = ['Reported Crime']
df_total_feb['Rank'] = df_total_feb['Reported Crime'].rank(ascending=0)
philadelphia_feb_max = df_total_feb['Reported Crime'].max()
philadelphia_feb_min = df_total_feb['Reported Crime'].min()


print(f'Febuary in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_feb["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_feb_max}')
print(f'The minimum crime committed on one day: {philadelphia_feb_min}')
print(f'Total crime on full moon (Feb 22nd): {philadelphia_crime_feb_22["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 7/30')
#df_total_feb
# Out:
# Febuary in Philadelphia:
# Total number of crimes reported: 12224
# Average number of crimes per day for whole month: 421
# The maximum crime committed on one day: 494
# The minimum crime committed on one day: 254
# Total crime on full moon (Feb 22nd): 465
# Percentage of monthy crime that occured on day of the full moon: 3.8%
# Rank of crime on full moon: 7/30

# %%
#Philadelphia Crime February Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_feb['Crime Date'].value_counts().sort_index()
days_month= list(range(1,30))
x=list(range(1,30))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,550)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('February 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=465, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/feb_2016.png')
plt.show()

# %%
#Philadelphia Crime March Data
philadelphia_crime_mar_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 3]
philadelphia_crime_mar = philadelphia_crime_mar_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_mar_23 = philadelphia_crime_mar[philadelphia_crime_mar['Crime Date'].dt.day == 23]

day_average = f'{((philadelphia_crime_mar_23["Crime Date"].count()/philadelphia_crime_mar["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_mar["Crime Date"].count()/31)}'

df_total_mar = pd.DataFrame(philadelphia_crime_mar['Crime Date'].value_counts())
df_total_mar.columns = ['Reported Crime']
df_total_mar['Rank'] = df_total_mar['Reported Crime'].rank(ascending=0)
philadelphia_mar_max = df_total_mar['Reported Crime'].max()
philadelphia_mar_min = df_total_mar['Reported Crime'].min()


print(f'March in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_mar["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_mar_max}')
print(f'The minimum crime committed on one day: {philadelphia_mar_min}')
print(f'Total crime on full moon (Mar 23rd): {philadelphia_crime_mar_23["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 1/31')
#df_total_mar
# Out:
# March in Philadelphia:
# Total number of crimes reported: 13931
# Average number of crimes per day for whole month: 449
# The maximum crime committed on one day: 540
# The minimum crime committed on one day: 316
# Total crime on full moon (Mar 23rd): 540
# Percentage of monthy crime that occured on day of the full moon: 3.88%
# Rank of crime on full moon: 1/31

# %%
#Philadelphia Crime March Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_mar['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('March 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=540, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/mar_2016.png')
plt.show()

# %%
#Philadelphia Crime April Data
philadelphia_crime_apr_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 4]
philadelphia_crime_apr = philadelphia_crime_apr_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_apr_22 = philadelphia_crime_apr[philadelphia_crime_apr['Crime Date'].dt.day == 22]

day_average = f'{((philadelphia_crime_apr_22["Crime Date"].count()/philadelphia_crime_apr["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_apr["Crime Date"].count()/30)}'

df_total_apr = pd.DataFrame(philadelphia_crime_apr['Crime Date'].value_counts())
df_total_apr.columns = ['Reported Crime']
df_total_apr['Rank'] = df_total_apr['Reported Crime'].rank(ascending=0)
philadelphia_apr_max = df_total_apr['Reported Crime'].max()
philadelphia_apr_min = df_total_apr['Reported Crime'].min()


print(f'April in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_apr["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_apr_max}')
print(f'The minimum crime committed on one day: {philadelphia_apr_min}')
print(f'Total crime on full moon (Apr 22nd): {philadelphia_crime_apr_22["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 4/30')
#df_total_apr
# Out:
# April in Philadelphia:
# Total number of crimes reported: 14170
# Average number of crimes per day for whole month: 472
# The maximum crime committed on one day: 552
# The minimum crime committed on one day: 364
# Total crime on full moon (Apr 22nd): 526
# Percentage of monthy crime that occured on day of the full moon: 3.71%
# Rank of crime on full moon: 4/30

# %%
#Philadelphia Crime aprch Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_apr['Crime Date'].value_counts().sort_index()
days_month= list(range(1,31))
x=list(range(1,31))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('April 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=526, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/apr_2016.png')
plt.show()

# %%
#Philadelphia Crime May Data
philadelphia_crime_may_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 5]
philadelphia_crime_may = philadelphia_crime_may_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_may_21 = philadelphia_crime_may[philadelphia_crime_may['Crime Date'].dt.day == 21]

day_average = f'{((philadelphia_crime_may_21["Crime Date"].count()/philadelphia_crime_may["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_may["Crime Date"].count()/31)}'

df_total_may = pd.DataFrame(philadelphia_crime_may['Crime Date'].value_counts())
df_total_may.columns = ['Reported Crime']
df_total_may['Rank'] = df_total_may['Reported Crime'].rank(ascending=0)
philadelphia_may_max = df_total_may['Reported Crime'].max()
philadelphia_may_min = df_total_may['Reported Crime'].min()


print(f'May in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_may["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_may_max}')
print(f'The minimum crime committed on one day: {philadelphia_may_min}')
print(f'Total crime on full moon (May 21st): {philadelphia_crime_may_21["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 16/31')
#df_total_may
# Out:
# May in Philadelphia:
# Total number of crimes reported: 15367
# Average number of crimes per day for whole month: 495
# The maximum crime committed on one day: 563
# The minimum crime committed on one day: 389
# Total crime on full moon (May 21st): 499
# Percentage of monthy crime that occured on day of the full moon: 3.25%
# Rank of crime on full moon: 16/31

# %%
#Philadelphia Crime May Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_may['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('May 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=499, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/may_2016.png')
plt.show()

# %%
#Philadelphia Crime June Data
philadelphia_crime_jun_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 6]
philadelphia_crime_jun = philadelphia_crime_jun_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_jun_20 = philadelphia_crime_jun[philadelphia_crime_jun['Crime Date'].dt.day == 20]

day_average = f'{((philadelphia_crime_jun_20["Crime Date"].count()/philadelphia_crime_jun["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_jun["Crime Date"].count()/30)}'

df_total_jun = pd.DataFrame(philadelphia_crime_jun['Crime Date'].value_counts())
df_total_jun.columns = ['Reported Crime']
df_total_jun['Rank'] = df_total_jun['Reported Crime'].rank(ascending=0)
philadelphia_jun_max = df_total_jun['Reported Crime'].max()
philadelphia_jun_min = df_total_jun['Reported Crime'].min()


print(f'June in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_jun["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_jun_max}')
print(f'The minimum crime committed on one day: {philadelphia_jun_min}')
print(f'Total crime on full moon (June 20th): {philadelphia_crime_jun_20["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 14/30')
#df_total_jun
# Out:
# June in Philadelphia:
# Total number of crimes reported: 15331
# Average number of crimes per day for whole month: 511
# The maximum crime committed on one day: 603
# The minimum crime committed on one day: 381
# Total crime on full moon (June 20th): 530
# Percentage of monthy crime that occured on day of the full moon: 3.46%
# Rank of crime on full moon: 14/30

# %%
#Philadelphia Crime June Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_jun['Crime Date'].value_counts().sort_index()
days_month= list(range(1,31))
x=list(range(1,31))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,700)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('June 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=530, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/jun_2016.png')
plt.show()

# %%
#Philadelphia Crime July Data
philadelphia_crime_jul_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 7]
philadelphia_crime_jul = philadelphia_crime_jul_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_jul_20 = philadelphia_crime_jul[philadelphia_crime_jul['Crime Date'].dt.day == 20]

day_average = f'{((philadelphia_crime_jul_20["Crime Date"].count()/philadelphia_crime_jul["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_jul["Crime Date"].count()/31)}'

df_total_jul = pd.DataFrame(philadelphia_crime_jul['Crime Date'].value_counts())
df_total_jul.columns = ['Reported Crime']
df_total_jul['Rank'] = df_total_jul['Reported Crime'].rank(ascending=0)
philadelphia_jul_max = df_total_jul['Reported Crime'].max()
philadelphia_jul_min = df_total_jul['Reported Crime'].min()


print(f'July in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_jul["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_jul_max}')
print(f'The minimum crime committed on one day: {philadelphia_jul_min}')
print(f'Total crime on full moon (July 20th): {philadelphia_crime_jul_20["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 13/31')
#df_total_jul
# Out:
# July in Philadelphia:
# Total number of crimes reported: 14174
# Average number of crimes per day for whole month: 457
# The maximum crime committed on one day: 558
# The minimum crime committed on one day: 349
# Total crime on full moon (July 20th): 468
# Percentage of monthy crime that occured on day of the full moon: 3.3%
# Rank of crime on full moon: 13/31

# %%
#Philadelphia Crime July Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_jul['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,700)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('July 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=568, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/jul_2016.png')
plt.show()

# %%
#Philadelphia Crime August Data
philadelphia_crime_aug_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 8]
philadelphia_crime_aug = philadelphia_crime_aug_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_aug_18= philadelphia_crime_aug[philadelphia_crime_aug['Crime Date'].dt.day == 18]

day_average = f'{((philadelphia_crime_aug_18["Crime Date"].count()/philadelphia_crime_aug["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_aug["Crime Date"].count()/31)}'

df_total_aug = pd.DataFrame(philadelphia_crime_aug['Crime Date'].value_counts())
df_total_aug.columns = ['Reported Crime']
df_total_aug['Rank'] = df_total_aug['Reported Crime'].rank(ascending=0)
philadelphia_aug_max = df_total_aug['Reported Crime'].max()
philadelphia_aug_min = df_total_aug['Reported Crime'].min()


print(f'August in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_aug["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_aug_max}')
print(f'The minimum crime committed on one day: {philadelphia_aug_min}')
print(f'Total crime on full moon (August 18th): {philadelphia_crime_aug_18["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 15/31')
#df_total_aug
# Out:
# August in Philadelphia:
# Total number of crimes reported: 15789
# Average number of crimes per day for whole month: 509
# The maximum crime committed on one day: 597
# The minimum crime committed on one day: 416
# Total crime on full moon (August 18th): 519
# Percentage of monthy crime that occured on day of the full moon: 3.29%
# Rank of crime on full moon: 15/31

# %%
#Philadelphia Crime August Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_aug['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,700)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('August 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=519, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/aug_2016.png')
plt.show()

# %%
#Philadelphia Crime September Data
philadelphia_crime_sep_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 9]
philadelphia_crime_sep = philadelphia_crime_sep_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_sep_16= philadelphia_crime_sep[philadelphia_crime_sep['Crime Date'].dt.day == 16]

day_average = f'{((philadelphia_crime_sep_16["Crime Date"].count()/philadelphia_crime_sep["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_sep["Crime Date"].count()/30)}'

df_total_sep = pd.DataFrame(philadelphia_crime_sep['Crime Date'].value_counts())
df_total_sep.columns = ['Reported Crime']
df_total_sep['Rank'] = df_total_sep['Reported Crime'].rank(ascending=0)
philadelphia_sep_max = df_total_sep['Reported Crime'].max()
philadelphia_sep_min = df_total_sep['Reported Crime'].min()


print(f'September in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_sep["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_sep_max}')
print(f'The minimum crime committed on one day: {philadelphia_sep_min}')
print(f'Total crime on full moon (September 16th): {philadelphia_crime_sep_16["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 2/30')
#df_total_sep
# Out:
# September in Philadelphia:
# Total number of crimes reported: 14482
# Average number of crimes per day for whole month: 482
# The maximum crime committed on one day: 565
# The minimum crime committed on one day: 396
# Total crime on full moon (September 16th): 540
# Percentage of monthy crime that occured on day of the full moon: 3.73%
# Rank of crime on full moon: 2/30

# %%
#Philadelphia Crime September Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_sep['Crime Date'].value_counts().sort_index()
days_month= list(range(1,31))
x=list(range(1,31))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('September 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=540, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/sep_2016.png')
plt.show()

# %%
#Philadelphia Crime October Data
philadelphia_crime_oct_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 10]
philadelphia_crime_oct = philadelphia_crime_oct_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_oct_16= philadelphia_crime_oct[philadelphia_crime_oct['Crime Date'].dt.day == 16]

day_average = f'{((philadelphia_crime_oct_16["Crime Date"].count()/philadelphia_crime_oct["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_oct["Crime Date"].count()/31)}'

df_total_oct = pd.DataFrame(philadelphia_crime_oct['Crime Date'].value_counts())
df_total_oct.columns = ['Reported Crime']
df_total_oct['Rank'] = df_total_oct['Reported Crime'].rank(ascending=0)
philadelphia_oct_max = df_total_oct['Reported Crime'].max()
philadelphia_oct_min = df_total_oct['Reported Crime'].min()


print(f'October in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_oct["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_oct_max}')
print(f'The minimum crime committed on one day: {philadelphia_oct_min}')
print(f'Total crime on full moon (October 16th): {philadelphia_crime_oct_16["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 28/31')
#df_total_oct
# Out:
# October in Philadelphia:
# Total number of crimes reported: 15311
# Average number of crimes per day for whole month: 493
# The maximum crime committed on one day: 584
# The minimum crime committed on one day: 397
# Total crime on full moon (October 16th): 430
# Percentage of monthy crime that occured on day of the full moon: 2.81%
# Rank of crime on full moon: 28/31

# %%
#Philadelphia Crime October Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_oct['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('October 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=430, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/oct_2016.png')
plt.show()

# %%
#Philadelphia Crime November Data
philadelphia_crime_nov_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 11]
philadelphia_crime_nov = philadelphia_crime_nov_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_nov_14= philadelphia_crime_nov[philadelphia_crime_nov['Crime Date'].dt.day == 14]

day_average = f'{((philadelphia_crime_nov_14["Crime Date"].count()/philadelphia_crime_nov["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_nov["Crime Date"].count()/30)}'

df_total_nov = pd.DataFrame(philadelphia_crime_nov['Crime Date'].value_counts())
df_total_nov.columns = ['Reported Crime']
df_total_nov['Rank'] = df_total_nov['Reported Crime'].rank(ascending=0)
philadelphia_nov_max = df_total_nov['Reported Crime'].max()
philadelphia_nov_min = df_total_nov['Reported Crime'].min()


print(f'November in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_nov["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_nov_max}')
print(f'The minimum crime committed on one day: {philadelphia_nov_min}')
print(f'Total crime on full moon (November 14th): {philadelphia_crime_nov_14["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 20/30')
#df_total_nov
# Out:
# November in Philadelphia:
# Total number of crimes reported: 13497
# Average number of crimes per day for whole month: 449
# The maximum crime committed on one day: 531
# The minimum crime committed on one day: 237
# Total crime on full moon (November 14th): 447
# Percentage of monthy crime that occured on day of the full moon: 3.31%
# Rank of crime on full moon: 20/30

# %%
#Philadelphia Crime November Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_nov['Crime Date'].value_counts().sort_index()
days_month= list(range(1,31))
x=list(range(1,31))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('November 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=447, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/nov_2016.png')
plt.show()

# %%
#Philadelphia Crime December Data
philadelphia_crime_dec_unsorted = philadelphia_crime_2016[philadelphia_crime_2016['Crime Date'].dt.month == 12]
philadelphia_crime_dec = philadelphia_crime_dec_unsorted.sort_values(by="Crime Date")

#To find value for day with full moon
philadelphia_crime_dec_14= philadelphia_crime_dec[philadelphia_crime_dec['Crime Date'].dt.day == 14]

day_average = f'{((philadelphia_crime_dec_14["Crime Date"].count()/philadelphia_crime_dec["Crime Date"].count())*100).round(2)}%'
monthly_average = f'{int(philadelphia_crime_dec["Crime Date"].count()/31)}'

df_total_dec = pd.DataFrame(philadelphia_crime_dec['Crime Date'].value_counts())
df_total_dec.columns = ['Reported Crime']
df_total_dec['Rank'] = df_total_dec['Reported Crime'].rank(ascending=0)
philadelphia_dec_max = df_total_dec['Reported Crime'].max()
philadelphia_dec_min = df_total_dec['Reported Crime'].min()


print(f'December in Philadelphia:')
print(f'Total number of crimes reported: {philadelphia_crime_dec["Crime Date"].count()}')
print(f'Average number of crimes per day for whole month: {monthly_average}')
print(f'The maximum crime committed on one day: {philadelphia_dec_max}')
print(f'The minimum crime committed on one day: {philadelphia_dec_min}')
print(f'Total crime on full moon (December 14th): {philadelphia_crime_dec_14["Crime Date"].count()}')
print(f'Percentage of monthy crime that occured on day of the full moon: {day_average}')
print(f'Rank of crime on full moon: 2/31')
#df_total_dec
# Out:
# December in Philadelphia:
# Total number of crimes reported: 12783
# Average number of crimes per day for whole month: 412
# The maximum crime committed on one day: 503
# The minimum crime committed on one day: 191
# Total crime on full moon (December 14th): 495
# Percentage of monthy crime that occured on day of the full moon: 3.87%
# Rank of crime on full moon: 2/31

# %%
#Philadelphia Crime December Plot
#Sort index by date and prepare for x-axis to be labeled by days alone
value_count = philadelphia_crime_dec['Crime Date'].value_counts().sort_index()
days_month= list(range(1,32))
x=list(range(1,32))

#Plot parameters
fig = plt.figure(figsize = (15,5))
plt.bar(days_month, value_count, width = .5)

#label plot
plt.xticks(x)
plt.tick_params(labelsize=16)
plt.xlabel('Days', fontsize=18)
plt.ylim(0,650)
plt.ylabel('Reported Crimes', fontsize=18)
plt.title('December 2016 Philadelphia Crime', fontsize=20)

#add line for day of full moon
plt.axhline(y=495, color='r', linewidth=2)

plt.legend(["Full Moon Crime"],prop={'size': 15})
fig.tight_layout()
plt.savefig('philadelphia_images/dec_2016.png')
plt.show()

# %%
#philadelphia crime over the year
full_moon_jan =int(philadelphia_crime_jan_24["Crime Date"].count())
full_moon_feb =int(philadelphia_crime_feb_22["Crime Date"].count())
full_moon_mar =int(philadelphia_crime_mar_23["Crime Date"].count())
full_moon_apr =int(philadelphia_crime_apr_22["Crime Date"].count())
full_moon_may =int(philadelphia_crime_may_21["Crime Date"].count())
full_moon_jun =int(philadelphia_crime_jun_20["Crime Date"].count())
full_moon_jul =int(philadelphia_crime_jul_20["Crime Date"].count())
full_moon_aug =int(philadelphia_crime_aug_18["Crime Date"].count())
full_moon_sep =int(philadelphia_crime_sep_16["Crime Date"].count())
full_moon_oct =int(philadelphia_crime_oct_16["Crime Date"].count())
full_moon_nov =int(philadelphia_crime_nov_14["Crime Date"].count())
full_moon_dec =int(philadelphia_crime_dec_14["Crime Date"].count())
philadelphia_year_crime = pd.DataFrame([['Jan', full_moon_jan, philadelphia_jan_max, philadelphia_jan_min],
                                  ['Feb', full_moon_feb, philadelphia_feb_max, philadelphia_feb_min],
                                  ['Mar', full_moon_mar, philadelphia_mar_max, philadelphia_mar_min],
                                  ['Apr', full_moon_apr, philadelphia_apr_max, philadelphia_apr_min],
                                  ['May', full_moon_may, philadelphia_may_max, philadelphia_may_min],
                                  ['June', full_moon_jun, philadelphia_jun_max, philadelphia_jun_min],
                                  ['July', full_moon_jul, philadelphia_jul_max, philadelphia_jul_min],
                                  ['Aug', full_moon_aug, philadelphia_aug_max, philadelphia_aug_min],
                                  ['Sept', full_moon_sep, philadelphia_sep_max, philadelphia_sep_min],
                                  ['Oct', full_moon_oct, philadelphia_oct_max, philadelphia_oct_min],
                                  ['Nov', full_moon_nov, philadelphia_nov_max, philadelphia_nov_min],
                                  ['Dec', full_moon_dec, philadelphia_dec_max, philadelphia_dec_min]],
                                columns=["Month", "Full Moon", "Max", "Min"])
philadelphia_year_crime
# Out:
#    Month  Full Moon  Max  Min
# 0    Jan        157  515   71
# 1    Feb        465  494  254
# 2    Mar        540  540  316
# 3    Apr        526  552  364
# 4    May        499  563  389
# 5   June        530  603  381
# 6   July        468  558  349
# 7    Aug        519  597  416
# 8   Sept        540  565  396
# 9    Oct        430  584  397
# 10   Nov        447  531  237
# 11   Dec        495  503  191

# %%
labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec' ]
y = (range(0, 12))
ax = philadelphia_year_crime[['Full Moon','Max', 'Min']].plot(kind='bar', figsize=(15, 10), legend=True, fontsize=18, rot=45)
ax.set_xticks(y)
ax.set_xticklabels(labels)
plt.xlabel('Months', fontsize=16)
plt.ylabel('Reported Crimes', fontsize=16)
plt.title('2016 Philadelphia Crime', fontsize=22)
plt.show()
plt.savefig('philadelphia_images/philadelphia_2016_compare.png')
